# %% [markdown]
# ## Ler arquivos TXT e extrair informações
#
# #### Os arquivos TXT estão incluídos no repositório do Github.
# #### Para obter os arquivos txt manualmente , é necessário instalar o programa pdftotext (``sudo apt-get install poppler-utils`` se não estiver instalado) e executar o arquivo ``pdf_to_txt.sh``na pasta ``/pdfs``
#
# Recomendamos rodar este notebook apenas se necessário, pois alguns erros ocorrem devido à falta de uniformidade dos PDFs (ver coluna 'error_flag'). O arquivo ``UC.csv`` foi criado de maneira semiautomática usando este script + ajuste manual, logo quaisquer mudanças nele devem ser feitas com cuidado.

# %%
import os
import os.path as osp
import pandas as pd
import numpy as np
import glob
import re


# Path to PDF folder
TXT_PATH = './txts'

e1 = ['nome', lambda X: re.search('Componente Curricular:(.*)\\n',X, re.IGNORECASE).group(1).strip()]
e2  = ['Pré-Requisitos', lambda X: re.search('Pré-requisitos?:(.*)\\n',X,re.IGNORECASE).group(1).strip()]
e3  = ['Carga Horária Total', lambda X: int(re.search('Carga Horária Total:\\D*(\\d+)\\D',X,re.IGNORECASE).group(1))]
e4  = ['Carga Horária Prática', lambda X: int(re.search('Carga Horária.* Prática:\\D*(\\d+)\\D',X,re.IGNORECASE).group(1))]
e5  = ['Carga Horária Teórica', lambda X: int(re.search('Carga Horária.* Teórica:\\D*(\\d+)\\D',X,re.IGNORECASE).group(1))]



def extract_text_info(path):
    """ 
        Reads .txt file from path, then uses regular expressions to fill a dictionary
        with the relevant information
    """
    
    # Get the string used to name the file
    file_ucname =  osp.split(path)[-1][:-4].replace('_', ' ')
    
    info = {'ucname_file':file_ucname , 'error_flag':False}
    
    
    with open(path) as file:
        text = '\r'.join(file.readlines())
    for f in [e1,e2,e3,e4,e5]:
        try:
            info[f[0]] = f[1](text)
        except:
            info['error_flag'] = True
            print(f'{file_ucname}: Failed to get "{f[0]}"')
    return info
    

# We store a list of file dictionaries 
file_dicts = []

for path in glob.glob(osp.join(TXT_PATH,'*.txt')):
    file_dicts.append(extract_text_info(path))
    
    
df = pd.DataFrame.from_records(file_dicts)
for c in ['nome','ucname_file','Pré-Requisitos']:
    df[c] = df[c].str.lower().str.strip().str.replace('.','',regex=False)
for c in df.columns:
    if c.startswith('Carga'):
        df.loc[pd.isna(df[c]), c] = -1
        df[c] = df[c].values.astype(np.int32)

df = df.sort_values('ucname_file')
# Out:
# Introdução à ecologia: Failed to get "Carga Horária Teórica"
# Blendas Poliméricas: Failed to get "Carga Horária Teórica"
#  Sustentabilidade no Gerenciamento de Resíduos: Failed to get "Carga Horária Prática"
# Processamento de materiais metálicos: Failed to get "Carga Horária Teórica"
# Laboratório de matemática: Failed to get "Carga Horária Teórica"
# Sistemas distribuídos: Failed to get "nome"
# Introdução à bioinformática: Failed to get "Carga Horária Teórica"
# Práticas em Projetos Extensionistas II: Failed to get "Carga Horária Teórica"
# Prática em Projetos Extensionistas I: Failed to get "Carga Horária Teórica"
# Práticas em Instrumentação Biomédica: Failed to get "nome"
# Práticas em Instrumentação Biomédica: Failed to get "Pré-Requisitos"
# Práticas em Instrumentação Biomédica: Failed to get "Carga Horária Total"
# Práticas em Instrumentação Biomédica: Failed to get "Carga Horária Prática"
# Práticas em Instrumentação Biomédica: Failed to get "Carga Horária Teórica"
# Modelagem de Dados: Failed to get "Carga Horária Teórica"

# %% [markdown]
# ___
# ## Visualizar DataFrame

# %%
display(df)
# Out:
#                              ucname_file  error_flag  \
# 39    algoritmos e estruturas de dados i       False
# 236  algoritmos e estruturas de dados ii       False
# 211         algoritmos em bioinformática       False
# 190                             anatomia       False
# 99                     análise de sinais       False
# ..                                   ...         ...
# 182  validação e verificação de software       False
# 113    vidros, vitrocerâmicas e vidrados       False
# 41                        álgebra linear       False
# 196         álgebra linear computacional       False
# 229                    álgebra linear ii       False
#
#                                     nome  \
# 39    algoritmos e estruturas de dados i
# 236  algoritmos e estruturas de dados ii
# 211         algoritmos em bioinformática
# 190                             anatomia
# 99                     análise de sinais
# ..                                   ...
# 182  validação e verificação de software
# 113    vidros, vitrocerâmicos e vidrados
# 41                        álgebra linear
# 196         álgebra linear computacional
# 229                    álgebra linear ii
#
#                                 Pré-Requisitos  Carga Horária Total  \
# 39                       lógica de programação                   72
# 236         algoritmos e estruturas de dados i                   72
# 211                      lógica de programação                   72
# 190                                     não há                   36
# 99   séries e equações diferenciais ordinárias                   72
# ..                                         ...                  ...
# 182                     engenharia de software                   72
# 113                        materiais cerâmicos                   72
# 41                         geometria analítica                   72
# 196                           cálculo numérico                   72
# 229                             álgebra linear                   72
#
#      Carga Horária Prática  Carga Horária Teórica
# 39                      36                     36
# 236                     26                     46
# 211                     36                     36
# 190                     10                     26
# 99                       0                     72
# ..                     ...                    ...
# 182                     36                     36
# 113                     18                     54
# 41                      10                     62
# 196                     22                     50
# 229                      0                     72
#
# [252 rows x 7 columns]

# %% [markdown]
# ---
# ## Testar se soma de prática e teórica dá a total

# %%
b = False == (df['Carga Horária Prática'] + df['Carga Horária Teórica'] == df['Carga Horária Total'])
df.loc[b,'error_flag'] = True
#display(df.loc[b,:])

# %% [markdown]
# ------
# ## Testar se nomes são iguais.

# %%
b = False == (df['nome']  == df['ucname_file'])
#df.loc[b,'error_flag'] = True
#display(df.loc[b,:])

# %% [markdown]
# # Salvar DataFrame em CSV

# %%
import csv

df2 = pd.read_csv('UC2.csv',quoting=csv.QUOTE_NONNUMERIC)
assert df2.ucname_file.isin(df.ucname_file).mean() == 1
# Use ucname_file as key
df = df.set_index(keys='ucname_file',drop=False)
df2 = df2.set_index(keys='ucname_file',drop=False)
df['Carga Horária Extensão'] = 0
for c in df2.columns:
    df.loc[df2.index,c] = df2[c]
df.to_csv('UC_manual.csv',index=False,quoting=csv.QUOTE_NONNUMERIC)
display(df)
# Out:
#                                                              ucname_file  \
# ucname_file
# algoritmos e estruturas de dados i    algoritmos e estruturas de dados i
# algoritmos e estruturas de dados ii  algoritmos e estruturas de dados ii
# algoritmos em bioinformática                algoritmos em bioinformática
# anatomia                                                        anatomia
# análise de sinais                                      análise de sinais
# ...                                                                  ...
# validação e verificação de software  validação e verificação de software
# vidros, vitrocerâmicas e vidrados      vidros, vitrocerâmicas e vidrados
# álgebra linear                                            álgebra linear
# álgebra linear computacional                álgebra linear computacional
# álgebra linear ii                                      álgebra linear ii
#
#                                      error_flag  \
# ucname_file
# algoritmos e estruturas de dados i        False
# algoritmos e estruturas de dados ii       False
# algoritmos em bioinformática              False
# anatomia                                  False
# análise de sinais                         False
# ...                                         ...
# validação e verificação de software       False
# vidros, vitrocerâmicas e vidrados         False
# álgebra linear                            False
# álgebra linear computacional              False
# álgebra linear ii                         False
#
#                                                                     nome  \
# ucname_file
# algoritmos e estruturas de dados i    algoritmos e estruturas de dados i
# algoritmos e estruturas de dados ii  algoritmos e estruturas de dados ii
# algoritmos em bioinformática                algoritmos em bioinformática
# anatomia                                                        anatomia
# análise de sinais                                      análise de sinais
# ...                                                                  ...
# validação e verificação de software  validação e verificação de software
# vidros, vitrocerâmicas e vidrados      vidros, vitrocerâmicos e vidrados
# álgebra linear                                            álgebra linear
# álgebra linear computacional                álgebra linear computacional
# álgebra linear ii                                      álgebra linear ii
#
#                                                                 Pré-Requisitos  \
# ucname_file
# algoritmos e estruturas de dados i                       lógica de programação
# algoritmos e estruturas de dados ii         algoritmos e estruturas de dados i
# algoritmos em bioinformática                             lógica de programação
# anatomia                                                                não há
# análise de sinais                    séries e equações diferenciais ordinárias
# ...                                                                        ...
# validação e verificação de software                     engenharia de software
# vidros, vitrocerâmicas e vidrados                          materiais cerâmicos
# álgebra linear                                             geometria analítica
# álgebra linear computacional                                  cálculo numérico
# álgebra linear ii                                               álgebra linear
#
#                                      Carga Horária Total  \
# ucname_file
# algoritmos e estruturas de dados i                    72
# algoritmos e estruturas de dados ii                   72
# algoritmos em bioinformática                          72
# anatomia                                              36
# análise de sinais                                     72
# ...                                                  ...
# validação e verificação de software                   72
# vidros, vitrocerâmicas e vidrados                     72
# álgebra linear                                        72
# álgebra linear computacional                          72
# álgebra linear ii                                     72
#
#                                      Carga Horária Prática  \
# ucname_file
# algoritmos e estruturas de dados i                      36
# algoritmos e estruturas de dados ii                     26
# algoritmos em bioinformática                            36
# anatomia                                                10
# análise de sinais                                        0
# ...                                                    ...
# validação e verificação de software                     36
# vidros, vitrocerâmicas e vidrados                       18
# álgebra linear                                          10
# álgebra linear computacional                            22
# álgebra linear ii                                        0
#
#                                      Carga Horária Teórica  \
# ucname_file
# algoritmos e estruturas de dados i                      36
# algoritmos e estruturas de dados ii                     46
# algoritmos em bioinformática                            36
# anatomia                                                26
# análise de sinais                                       72
# ...                                                    ...
# validação e verificação de software                     36
# vidros, vitrocerâmicas e vidrados                       54
# álgebra linear                                          62
# álgebra linear computacional                            50
# álgebra linear ii                                       72
#
#                                      Carga Horária Extensão
# ucname_file
# algoritmos e estruturas de dados i                        0
# algoritmos e estruturas de dados ii                       0
# algoritmos em bioinformática                              0
# anatomia                                                  0
# análise de sinais                                         0
# ...                                                     ...
# validação e verificação de software                       0
# vidros, vitrocerâmicas e vidrados                         0
# álgebra linear                                            0
# álgebra linear computacional                              0
# álgebra linear ii                                         0
#
# [252 rows x 8 columns]

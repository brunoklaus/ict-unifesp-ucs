# %%
import os
import os.path as osp
import pandas as pd
import numpy as np
import re
import csv

CSV_PATH = './UC.csv'
MATRIZES_ROOT = './matrizes'
TRAJECTORY_ROOT = MATRIZES_ROOT
TRAJECTORY_FNAME = 'engbio.txt'

# Read CSV
df = pd.read_csv(CSV_PATH,quoting=csv.QUOTE_NONNUMERIC)


def restrict_to_trajectory(df, path_to_txt):
    # Map values at columns to id
    dct = {value:key for key,value in df['ucname_file'].to_dict().items()}
    dct.update({value:key for key,value in df['nome'].to_dict().items()})
    
    fname = osp.split(path_to_txt)[-1].split('.txt')[0]

    with open(path_to_txt,'r') as f:
        nodes = [x.lower().strip() for x in f.readlines()]
        nodes = [x for x in nodes if len(x) > 0]
        for n in nodes:
            if not n in dct:
                print(n)
                raise ''
        df1 = df.loc[df.ucname_file.isin(nodes),:].copy()
        df1 = df1.reset_index(drop=True)
    return df1
if TRAJECTORY_FNAME is not None:
    if not TRAJECTORY_FNAME.endswith('.txt'):
        raise Exception('Trajectory file must end with .txt')
    tpath = osp.join(TRAJECTORY_ROOT, TRAJECTORY_FNAME)
    print(tpath)
    df = restrict_to_trajectory(df, path_to_txt=tpath)
display(df)
# Out:
# ./matrizes/engbio.txt
#                                   ucname_file  error_flag  \
# 0                algoritmos em bioinformática       False
# 1                                    anatomia       False
# 2                           análise de sinais       False
# 3             avanços em engenharia biomédica       False
# 4                               bioengenharia       False
# 5                                biomateriais       False
# 6                                 biomecânica       False
# 7                                biossensores       False
# 8                          circuitos digitais       False
# 9                       circuitos elétricos i       False
# 10                     circuitos elétricos ii       False
# 11            ciência, tecnologia e sociedade       False
# 12  ciência, tecnologia, sociedade e ambiente       False
# 13             controle de sistemas dinâmicos       False
# 14                    cálculo em uma variável       False
# 15                cálculo em várias variáveis       False
# 16                           cálculo numérico       False
# 17                     desenho técnico básico       False
# 18                        eletrônica avançada       False
# 19              engenharia clínica hospitalar       False
# 20                 engenharia médica aplicada       False
# 21                      fenômenos do contínuo       False
# 22         fenômenos do contínuo experimental       False
# 23                 fenômenos eletromagnéticos       False
# 24    fenômenos eletromagnéticos experimental       False
# 25                        fenômenos mecânicos       False
# 26           fenômenos mecânicos experimental       False
# 27                        fisiologia humana i       False
# 28                       fisiologia humana ii       False
# 29            fundamentos de biologia moderna       False
# 30                        geometria analítica       False
# 31                         imagens biomédicas       False
# 32                 instrumentos eletromédicos       False
# 33                 introdução à eletrotécnica       False
# 34         laboratório de circuitos elétricos       False
# 35          laboratório de eletrônica digital       False
# 36                      lógica de programação       False
# 37                             mecânica geral       False
# 38                              microeconomia       False
# 39                probabilidade e estatística       False
# 40                    processamento de sinais       False
# 41                              química geral       False
# 42                 química geral experimental       False
# 43                        sistemas embarcados       False
# 44                         sistemas mecânicos       False
# 45  séries e equações diferenciais ordinárias       False
# 46                    teorias administrativas       False
# 47         transdução de grandezas biomédicas       False
# 48                             álgebra linear       False
#
#                                          nome  \
# 0                algoritmos em bioinformática
# 1                                    anatomia
# 2                           análise de sinais
# 3             avanços em engenharia biomédica
# 4                               bioengenharia
# 5                                biomateriais
# 6                                 biomecânica
# 7                                biossensores
# 8                          circuitos digitais
# 9                       circuitos elétricos i
# 10                     circuitos elétricos ii
# 11            ciência, tecnologia e sociedade
# 12  ciência, tecnologia, sociedade e ambiente
# 13             controle de sistemas dinâmicos
# 14                    cálculo em uma variável
# 15                cálculo em várias variáveis
# 16                           cálculo numérico
# 17                     desenho técnico básico
# 18                        eletrônica avançada
# 19     engenharia clinica hospitalar aplicada
# 20                 engenharia médica aplicada
# 21                      fenômenos do contínuo
# 22         fenômenos do contínuo experimental
# 23                 fenômenos eletromagnéticos
# 24    fenômenos eletromagnéticos experimental
# 25                        fenômenos mecânicos
# 26           fenômenos mecânicos experimental
# 27                          fisiologia humana
# 28                       fisiologia humana ii
# 29            fundamentos da biologia moderna
# 30                        geometria analítica
# 31                         imagens biomédicas
# 32                 instrumentos eletromédicos
# 33                 introdução à eletrotécnica
# 34         laboratório de circuitos elétricos
# 35          laboratório de eletrônica digital
# 36                      lógica de programação
# 37                             mecânica geral
# 38                              microeconomia
# 39                probabilidade e estatística
# 40                    processamento de sinais
# 41                              química geral
# 42                 química geral experimental
# 43                        sistemas embarcados
# 44                         sistemas mecânicos
# 45  séries e equações diferenciais ordinárias
# 46                    teorias administrativas
# 47         transdução de grandezas biomédicas
# 48                             álgebra linear
#
#                                        Pré-Requisitos  Carga Horária Total  \
# 0                               lógica de programação                 72.0
# 1                                              não há                 36.0
# 2           séries e equações diferenciais ordinárias                 72.0
# 3     sistemas embarcados; instrumentos eletromédicos                 36.0
# 4                                 fisiologia humana i                 72.0
# 5                                       química geral                 36.0
# 6                                  sistemas mecânicos                 72.0
# 7   química geral; fenômenos eletromagnéticos; fun...                 72.0
# 8                                              não há                 72.0
# 9                                              não há                 72.0
# 10  circuitos elétricos i; fenômenos eletromagnéticos                 72.0
# 11                                             não há                 36.0
# 12                                             não há                 36.0
# 13          análise de sinais; circuitos elétricos ii                 72.0
# 14                                             não há                108.0
# 15       cálculo em uma variável; geometria analítica                 72.0
# 16       cálculo em uma variável; geometria analítica                 72.0
# 17                                             não há                 36.0
# 18                             circuitos elétricos ii                 72.0
# 19                         introdução à eletrotécnica                 72.0
# 20  fisiologia humana; imagens biomédicas; transdu...                 72.0
# 21                                             não há                 72.0
# 22                                             não há                 36.0
# 23                                             não há                 72.0
# 24                                             não há                 36.0
# 25                                             não há                 72.0
# 26                                             não há                 36.0
# 27                                             não há                 72.0
# 28                                fisiologia humana i                 72.0
# 29                                             não há                 72.0
# 30                                             não há                 72.0
# 31    análise de sinais; algoritmos em bioinformática                 72.0
# 32                             circuitos elétricos ii                 72.0
# 33                             circuitos elétricos ii                 36.0
# 34  fenômenos eletromagnéticos; circuitos elétricos i                 36.0
# 35                                 circuitos digitais                 36.0
# 36                                             não há                 72.0
# 37           geometria analítica; fenômenos mecânicos                 72.0
# 38                                             não há                 36.0
# 39                            cálculo em uma variável                 72.0
# 40    análise de sinais; algoritmos em bioinformática                 36.0
# 41                                             não há                 72.0
# 42                                             não há                 72.0
# 43                                             não há                 72.0
# 44                                     mecânica geral                 72.0
# 45                            cálculo em uma variável                 72.0
# 46                                             não há                 36.0
# 47                             circuitos elétricos ii                 72.0
# 48                                geometria analítica                 72.0
#
#     Carga Horária Prática  Carga Horária Teórica  Carga Horária Extensão
# 0                    36.0                   36.0                     0.0
# 1                    10.0                   26.0                     0.0
# 2                     0.0                   72.0                     0.0
# 3                    36.0                    0.0                     0.0
# 4                     0.0                   72.0                     0.0
# 5                     0.0                   36.0                     0.0
# 6                    36.0                   36.0                     0.0
# 7                     0.0                   72.0                     0.0
# 8                    20.0                   52.0                     0.0
# 9                     0.0                   72.0                     0.0
# 10                    0.0                   72.0                     0.0
# 11                    0.0                   36.0                     0.0
# 12                    0.0                   36.0                     0.0
# 13                   36.0                   36.0                     0.0
# 14                   36.0                   72.0                     0.0
# 15                   10.0                   62.0                     0.0
# 16                   14.0                   58.0                     0.0
# 17                   18.0                   18.0                     0.0
# 18                    8.0                   64.0                     0.0
# 19                   36.0                   36.0                     0.0
# 20                   36.0                   36.0                     0.0
# 21                    0.0                   72.0                     0.0
# 22                   36.0                    0.0                     0.0
# 23                    0.0                   72.0                     0.0
# 24                   36.0                    0.0                     0.0
# 25                    0.0                   72.0                     0.0
# 26                   36.0                    0.0                     0.0
# 27                   12.0                   60.0                     0.0
# 28                   12.0                   60.0                     0.0
# 29                    0.0                   72.0                     0.0
# 30                    8.0                   64.0                     0.0
# 31                   36.0                   36.0                     0.0
# 32                   12.0                   60.0                     0.0
# 33                    0.0                   36.0                     0.0
# 34                   36.0                    0.0                     0.0
# 35                   36.0                    0.0                     0.0
# 36                   30.0                   42.0                     0.0
# 37                    0.0                   72.0                     0.0
# 38                    0.0                   36.0                     0.0
# 39                   16.0                   56.0                     0.0
# 40                   36.0                    0.0                     0.0
# 41                    0.0                   72.0                     0.0
# 42                   72.0                    0.0                     0.0
# 43                   36.0                   36.0                     0.0
# 44                    0.0                   72.0                     0.0
# 45                   10.0                   62.0                     0.0
# 46                    0.0                   36.0                     0.0
# 47                   20.0                   52.0                     0.0
# 48                   10.0                   62.0                     0.0

# %%
def get_edges(df):
    """ Creates list of tuples representing directed edges. 
        The values in each tuple are taken from the ``ucname_file`` column.
    
        Returns:
            List[Tuple[str,str]]
    """
    
    # Create 'id' attribute
    df['id'] = np.arange(df.shape[0])

    # Map values at columns to id
    dct = {value:key for key,value in df['ucname_file'].to_dict().items()}
    dct.update({value:key for key,value in df['nome'].to_dict().items()})

    edges = []
    for i, row in df.iterrows():
        prs = row['Pré-Requisitos'].strip().replace(',',';').split(';')
        name1 = row['ucname_file']
        name2 =  row['nome']
        for pr in prs:
            pr = pr.strip()
            if re.search('não há',pr) is not None:
                break
            if len(pr) == 0:
                continue
            if pr not in dct:
                print(f"'{pr}' not found in dictionary, but present in {name1}")
            else:
                edges.append( (df['ucname_file'].values[dct[pr]], name1))
    return edges     
def get_edge_dataframe(edges):
    return pd.DataFrame({'A':[x[0] for x in edges],'B':[x[1] for x in edges]})

edges = get_edges(df)
df_edges = get_edge_dataframe(edges)

# Get output path
df_edges_fpath = osp.join(TRAJECTORY_ROOT,'edges.csv')
if TRAJECTORY_FNAME is not None:
    df_edges_fpath = osp.join(TRAJECTORY_ROOT,TRAJECTORY_FNAME.split('.txt')[0] + '_edges.csv')
    
# Save to CSV
df_edges.to_csv(df_edges_fpath,index=False)
print('saved to ' + df_edges_fpath)
# Out:
# saved to ./matrizes/engbio_edges.csv

# %%
import networkx as nx
def create_graph(df, edges):
    """ Creates a NetworkX graph from the node dataframe and edge list.
    
        df (pd.DataFrame): node dataframe.
        edges (List[Tuple[str,str]]): list of directed edges.
        
        Returns:
            nx.Digraph
    """
    df_mini = df.loc[:,['ucname_file']].rename(columns={'ucname_file':'id'})
    
    G = nx.DiGraph()
    nodes = []
    for i, row in df_mini.iterrows():
        nodes.append((i, row.to_dict()) )
    G.add_nodes_from(nodes)
    G.add_edges_from(edges)
    G.remove_nodes_from(range(df.shape[0]))
    return G

def add_topological_info(df,G):
    """ Add information to later be used for the interactive visualization. """
    num_gen = len(list(nx.topological_generations(G)))
    df['group'] = '000'
    for i, gen in  enumerate(nx.topological_generations(G)):
        b = df['ucname_file'].isin(gen)
        df.loc[b,'group'] = str(num_gen-i).zfill(3)
        df.loc[b,'topgen'] = str(i)
        
    num_gen = len(list(nx.topological_generations(G.reverse(copy=True))))
    for i, gen in  enumerate(nx.topological_generations(G.reverse(copy=True))):
        b = df['ucname_file'].isin(gen)
        df.loc[b,'size'] = 1 + i
    

    
# Create graph
G = create_graph(df, edges)
add_topological_info(df,G)

# Get output path
df_fpath = 'nodes.txt'
df_nodes_fpath = osp.join(TRAJECTORY_ROOT,'nodes.csv')
if TRAJECTORY_FNAME is not None:
    df_nodes_fpath = osp.join(TRAJECTORY_ROOT,TRAJECTORY_FNAME .split('.txt')[0] + '_nodes.csv')

# Save node CSV
df.to_csv(df_nodes_fpath,index=False,quoting=csv.QUOTE_NONNUMERIC)
print('saved to ' + df_nodes_fpath)
# Out:
# saved to ./matrizes/engbio_nodes.csv

# %%
print(df1.shape,df2.shape, df.shape)
# Out:
# (49, 11) (40, 2) (49, 12)
